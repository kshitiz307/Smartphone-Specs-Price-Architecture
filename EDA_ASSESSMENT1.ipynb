# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/sample_data/1000 Sales Records.csv")

print("Original DataFrame")
df.head()
# Out:
# Original DataFrame
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df1 = df.iloc[:500]
df2 = df.iloc[500:]

concat_df = pd.concat([df1, df2])

print(concat_df.head())
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
left = df[['Region', 'Country']]
right = df[['Country', 'Sales Channel']]

merged_df = pd.merge(left, right, on='Country')

print(merged_df.head())
# Out:
#                          Region Country Sales Channel
# 0  Middle East and North Africa   Libya       Offline
# 1  Middle East and North Africa   Libya       Offline
# 2  Middle East and North Africa   Libya       Offline
# 3  Middle East and North Africa   Libya       Offline
# 4  Middle East and North Africa   Libya        Online

# %%
df['Profit'] = df['Total Profit']

print(df.head())
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit      Profit
# ...

# %%
print(df.describe())
# Out:
#            Order ID   Units Sold  Unit Price    Unit Cost  Total Revenue  \
# count  1.000000e+03  1000.000000  1000.00000  1000.000000   1.000000e+03
# mean   5.496813e+08  5053.988000   262.10684   184.965110   1.327322e+06
# std    2.571334e+08  2901.375317   216.02106   175.289311   1.486515e+06
# min    1.029280e+08    13.000000     9.33000     6.920000   2.043250e+03
# 25%    3.280740e+08  2420.250000    81.73000    56.670000   2.811919e+05
# 50%    5.566097e+08  5184.000000   154.06000    97.440000   7.549392e+05
# 75%    7.696945e+08  7536.750000   421.89000   263.330000   1.733503e+06
# max    9.955298e+08  9998.000000   668.27000   524.960000   6.617210e+06
#
#          Total Cost  Total Profit        Profit
# count  1.000000e+03  1.000000e+03  1.000000e+03
# mean   9.361192e+05  3.912026e+05  3.912026e+05
# std    1.162571e+06  3.836402e+05  3.836402e+05
# min    1.416750e+03  5.326100e+02  5.326100e+02
# 25%    1.649319e+05  9.837612e+04  9.837612e+04
# ...

# %%
print(df['Region'].value_counts())

# %%
hier_df = df.set_index(['Region', 'Country'])

print(hier_df.head())
# Out:
#                                        Item Type Sales Channel Order Priority  \
# Region                       Country
# Middle East and North Africa Libya     Cosmetics       Offline              M
# North America                Canada   Vegetables        Online              M
# Middle East and North Africa Libya     Baby Food       Offline              C
# Asia                         Japan        Cereal       Offline              C
# Sub-Saharan Africa           Chad         Fruits       Offline              H
#
#                                       Order Date   Order ID   Ship Date  \
# Region                       Country
# Middle East and North Africa Libya    10/18/2014  686800706  10/31/2014
# North America                Canada    11/7/2011  185941302   12/8/2011
# Middle East and North Africa Libya    10/31/2016  246222341   12/9/2016
# Asia                         Japan     4/10/2010  161442649   5/12/2010
# ...

# %%
s1 = pd.Series([10, 20, 30])
s2 = pd.Series([40, 50, 60])

result = pd.concat([s1, s2], keys=['Series1', 'Series2'])

print(result)
# Out:
# Series1  0    10
#          1    20
#          2    30
# Series2  0    40
#          1    50
#          2    60
# dtype: int64

# %%
df.to_csv("Updated_1000_Sales_Records.csv", index=False)
